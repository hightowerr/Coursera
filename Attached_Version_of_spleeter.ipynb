# %% [markdown]
# <a href="https://colab.research.google.com/github/hightowerr/Coursera/blob/main/Attached_Version_of_spleeter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install spleeter

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
pip install spleeter

# %%
from IPython.display import Audio

# %% [markdown]
# # Separate from command line

# %%
# !wget https://github.com/hightowerr/hello-world/raw/master/Attached.mp3
# Out:
# --2021-08-01 13:23:40--  https://github.com/hightowerr/hello-world/raw/master/Attached.mp3
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hightowerr/hello-world/master/Attached.mp3 [following]
# --2021-08-01 13:23:41--  https://raw.githubusercontent.com/hightowerr/hello-world/master/Attached.mp3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2314502 (2.2M) [audio/mpeg]
# Saving to: ‘Attached.mp3.1’
#
# Attached.mp3.1      100%[===================>]   2.21M  --.-KB/s    in 0.08s
#
# 2021-08-01 13:23:41 (28.0 MB/s) - ‘Attached.mp3.1’ saved [2314502/2314502]

# %%
Audio('Attached.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !spleeter separate -h
# Out:
# Usage: spleeter separate [OPTIONS] FILES...
# Try 'spleeter separate --help' for help.
#
# Error: no such option: -h

# %%
# !spleeter separate -o output/ Attached.mp3
# Out:
# INFO:spleeter:File output/Attached/vocals.wav written succesfully
# INFO:spleeter:File output/Attached/accompaniment.wav written succesfully

# %%
# !ls output/Attached
# Out:
# accompaniment.wav  vocals.wav

# %%
Audio('output/Attached/vocals.wav')

# %%
Audio('output/Attached/accompaniment.wav')
